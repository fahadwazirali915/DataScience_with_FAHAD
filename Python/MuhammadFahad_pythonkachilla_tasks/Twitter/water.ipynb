# %%
# import Libraries !
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import seaborn as sns
import plotly.express as px

# %%
asia_water = pd.read_csv("south_asia_drinkingWater.csv")
asia_water.head(2)
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6121   Value      21047
# 1          6121   Value      21048
#
#                                                 Item  Year Code  Year Unit  \
# 0  Percentage of population using at least basic ...       2000  2000    %
# 1  Percentage of population using at least basic ...       2000  2000    %
#
#    Value Flag                Flag Description  Note
# 0   87.2    X  International reliable sources   NaN
# 1   29.6    X  International reliable sources   NaN

# %%
type(asia_water["Year"])
# Out:
# pandas.core.series.Series

# %%
asia_water =asia_water[asia_water['Year']>=2010]
asia_water.Year.min()
# Out:
# 2010

# %%
plt.figure(figsize=(12,6))
sns.set_theme(style="darkgrid", color_codes=True)
sns.lineplot(x="Year",
            y="Value",
            hue="Area",
            data=asia_water,
            palette="Set1")
plt.title("Drinking Water in South Asia (2000-2020)", weight="bold", fontsize="16") 
plt.xlabel("Years", weight="bold") 
plt.ylabel("Values", weight="bold") 
plt.show()

# %%
sns.set_theme(style="darkgrid", color_codes=True)
sns.boxplot(data=asia_water,
                y="Value",
            palette="Set2")
plt.show()

# %%
asia_water.Value.max()
# Out:
# 99.0

# %%
asia_water.isnull().sum()
# Out:
# Domain Code           0
# Domain                0
# Area Code             0
# Area                  0
# Element Code          0
# Element               0
# Item Code             0
# Item                  0
# Year Code             0
# Year                  0
# Unit                  0
# Value                 0
# Flag                  0
# Flag Description      0
# Note                198
# dtype: int64
