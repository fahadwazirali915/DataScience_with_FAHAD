# %%
# import Libraries !
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dim = sns.load_dataset("diamonds")
dim
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
dim.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.set_theme(style="whitegrid", color_codes=True)
sns.boxplot(x="cut",
            y="depth",
            data=dim,
            palette="Set2")
plt.title("Diamonds View", weight="bold")
plt.show()

# %%
sns.set_theme(style="whitegrid", color_codes=True)
sns.boxplot(x="color",
            y="price",
            hue="cut",
            data=dim,
            palette="Set1")
plt.title("Diamonds View", weight="bold")
plt.show()

# %%
dim.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dim.mean()
# Out:
# C:\Users\fahad\AppData\Local\Temp\ipykernel_14480\1288693814.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dim.mean()
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
dim.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
dim = dim.drop(["table"], axis=1)
dim.head()
# Out:
#    carat      cut color clarity  depth  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3    335  4.34  4.35  2.75

# %%
dim.groupby(["cut"]).mean()
# Out:
#               carat      depth        price         x         y         z
# cut
# Ideal      0.702837  61.709401  3457.541970  5.507451  5.520080  3.401448
# Premium    0.891955  61.264673  4584.257704  5.973887  5.944879  3.647124
# Very Good  0.806381  61.818275  3981.759891  5.740696  5.770026  3.559801
# Good       0.849185  62.365879  3928.864452  5.838785  5.850744  3.639507
# Fair       1.046137  64.041677  4358.757764  6.246894  6.182652  3.982770

# %%
dim[dim["depth"] > 70].groupby(["color"]).mean()
# Out:
#           carat      depth        price       x         y         z
# color
# D      0.860000  71.100000  3047.000000  5.7750  5.645000  4.060000
# E      0.682500  76.700000  2062.000000  5.3975  5.325000  4.102500
# F      1.066667  70.666667  5652.000000  5.9600  5.903333  4.186667
# G      1.376000  71.220000  6468.800000  6.5420  6.270000  4.506000
# H      1.480000  71.040000  4549.200000  6.6900  6.612000  4.720000
# I      1.243333  70.733333  3248.333333  6.4400  6.333333  4.516667
# J      0.990000  73.600000  1789.000000  6.0100  5.800000  4.350000

# %% [markdown]
# ---
